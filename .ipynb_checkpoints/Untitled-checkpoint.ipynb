# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1 = pd.read_csv("41467_2019_12808_MOESM4_ESM.csv")
print(df1.shape)
df1.head()
# Out:
# (1768, 27)
#    Place   Total        SeaLevel CoastalDEM_Perm_p5  CoastalDEM_Perm_p50  \
# 0  World  6800.0     Present day                 --                110.0
# 1  World  6800.0  K14_rcp26_2050                130                150.0
# 2  World  6800.0  K14_rcp26_2100                150                190.0
# 3  World  6800.0  K14_rcp45_2050                140                150.0
# 4  World  6800.0  K14_rcp45_2100                160                200.0
#
#   CoastalDEM_Perm_p95 CoastalDEM_RL1_p5  CoastalDEM_RL1_p50  \
# 0                  --                --               250.0
# 1                 160               270               300.0
# 2                 250               300               340.0
# 3                 170               280               300.0
# 4                 260               310               360.0
#
#   CoastalDEM_RL1_p95 SRTM_Perm_p5  ...  JAXA_Perm_p95 JAXA_RL1_p5  \
# 0                 --           --  ...             --          --
# ...

# %%
df2 = pd.read_csv("41467_2019_12808_MOESM5_ESM.csv")
print(df2.shape)
df2.head()
# Out:
# (175, 13)
#             PLACE_NAME   TOTAL      x0m     x1m     x2m     x3m     x4m  \
# 0              Albania   3.000  0.05000  0.1200  0.1600  0.2300  0.2800
# 1              Algeria  35.000  0.03500  0.0540  0.3600  0.7500  0.9600
# 2       American Samoa   0.066  0.00250  0.0050  0.0070  0.0086  0.0098
# 3               Angola  13.000  0.00380  0.0140  0.1300  0.2900  0.3700
# 4  Antigua and Barbuda   0.087  0.00036  0.0015  0.0036  0.0093  0.0130
#
#      x5m    x6m    x7m    x8m    x9m   x10m
# 0  0.320  0.350  0.380  0.410  0.440  0.470
# 1  1.100  1.200  1.300  1.400  1.500  1.600
# 2  0.011  0.012  0.013  0.014  0.015  0.015
# 3  0.430  0.480  0.510  0.540  0.570  0.590
# 4  0.016  0.018  0.020  0.021  0.023  0.024

# %%
df3 = pd.read_csv("41467_2019_12808_MOESM6_ESM.csv")
print(df3.shape)
df3.head()
# Out:
# (176, 13)
#             PLACE_NAME   TOTAL        0m      1m      2m      3m      4m  \
# 0              Albania   3.000  0.000088  0.0120  0.1300  0.1600  0.1900
# 1              Algeria  35.000  0.001500  0.0630  0.1300  0.2500  0.4200
# 2       American Samoa   0.066  0.000980  0.0015  0.0023  0.0036  0.0049
# 3               Angola  13.000  0.000180  0.0027  0.0069  0.0150  0.0600
# 4  Antigua and Barbuda   0.087  0.000900  0.0018  0.0028  0.0041  0.0060
#
#        5m      6m      7m      8m     9m    10m
# 0  0.2300  0.2500  0.2800  0.3000  0.330  0.350
# 1  0.5400  0.6400  0.7500  0.8700  0.970  1.100
# 2  0.0062  0.0074  0.0085  0.0096  0.011  0.011
# 3  0.1100  0.1600  0.2100  0.2600  0.310  0.370
# 4  0.0083  0.0110  0.0130  0.0150  0.016  0.018

# %%
df4 = pd.read_csv("41467_2019_12808_MOESM7_ESM.csv")
print(df4.shape)
df4.head()
# Out:
# (2548, 27)
#    Place   Total        SeaLevel CoastalDEM_Perm_p5  CoastalDEM_Perm_p50  \
# 0  World  6800.0     Present day                 --                  1.7
# 1  World  6800.0  K14_rcp26_2050                2.0                  2.2
# 2  World  6800.0  K14_rcp26_2100                2.3                  2.8
# 3  World  6800.0  K14_rcp45_2050                2.0                  2.2
# 4  World  6800.0  K14_rcp45_2100                2.4                  3.0
#
#   CoastalDEM_Perm_p95 CoastalDEM_RL1_p5  CoastalDEM_RL1_p50  \
# 0                  --                --                 3.6
# 1                 2.4               4.0                 4.3
# 2                 3.6               4.4                 5.0
# 3                 2.4               4.1                 4.4
# 4                 3.9               4.5                 5.2
#
#   CoastalDEM_RL1_p95 SRTM_Perm_p5  ...  JAXA_Perm_p95 JAXA_RL1_p5  \
# 0                 --           --  ...             --          --
# ...

# %%
df5 = pd.read_csv("41467_2019_12808_MOESM8_ESM.csv")
print(df5.shape)
df5.head()
# Out:
# (192, 21)
#        PLACE_NAME  TOTAL_POP  VAL_NO_NOISE  VAL_1PX_p5  VAL_1PX_p50  \
# 0         Albania     3000.0        160.00      150.00       150.00
# 1         Algeria    35000.0        350.00      400.00       420.00
# 2  American Samoa       66.0          7.00        6.00         6.40
# 3          Angola    13000.0        130.00      140.00       170.00
# 4        Anguilla       15.0          0.53        0.52         0.59
#
#    VAL_1PX_p95  VAL_1KM_p5  VAL_1KM_p50  VAL_1KM_p95  VAL_1_10DEG_p5  ...  \
# 0       150.00      130.00       150.00       170.00            88.0  ...
# 1       440.00      320.00       420.00       480.00           250.0  ...
# 2         6.70        5.10         6.60         7.80             2.8  ...
# 3       190.00      130.00       180.00       240.00            39.0  ...
# 4         0.66        0.41         0.63         0.91             0.1  ...
#
#    VAL_1_10DEG_p95  VAL_1_4DEG_p5  VAL_1_4DEG_p50  VAL_1_4DEG_p95  \
# ...

# %%
df5.columns
# Out:
# Index(['PLACE_NAME', 'TOTAL_POP', 'VAL_NO_NOISE', 'VAL_1PX_p5', 'VAL_1PX_p50',
#        'VAL_1PX_p95', 'VAL_1KM_p5', 'VAL_1KM_p50', 'VAL_1KM_p95',
#        'VAL_1_10DEG_p5', 'VAL_1_10DEG_p50', 'VAL_1_10DEG_p95', 'VAL_1_4DEG_p5',
#        'VAL_1_4DEG_p50', 'VAL_1_4DEG_p95', 'VAL_1_2DEG_p5', 'VAL_1_2DEG_p50',
#        'VAL_1_2DEG_p95', 'VAL_1DEG_p5', 'VAL_1DEG_p50', 'VAL_1DEG_p95'],
#       dtype='object')

# %%
df6=pd.read_excel("slr-impacts_nov2010.xls")
print(df6.shape)
df6.head(20)
# Out:
# (110, 13)
#    Reference: The Impact of Sea-Level rise on Developing Countries: A Comparative Analysis by Dasgupta, Laplante, Meisner, Wheeler and Yan   \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                             Country
# 4                                                Code
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                ARG
# 11                                                BHS
# 12                                                BLZ
# 13                                                BRA
# 14                                                CHL
# ...

# %%
df6.dropna().head()
# Out:
#    Reference: The Impact of Sea-Level rise on Developing Countries: A Comparative Analysis by Dasgupta, Laplante, Meisner, Wheeler and Yan   \
# 10                                                ARG
# 11                                                BHS
# 12                                                BLZ
# 13                                                BRA
# 14                                                CHL
#
#    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 10  Argentina    2736391       9083      14331      20131      25362
# 11    Bahamas      13162       1523       2507       4080       6165
# 12     Belize      22290        424        752       1089       1396
# 13     Brazil    8480395      11456      20673      34564      43970
# 14      Chile     721229       7266       9280      11249      12923
#
#    Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12
# ...

# %%
df7=pd.read_csv("slr_sla_gbl_free_all_66.csv",sep='delimiter',skiprows=5,error_bad_lines=False)
print(df7.shape)
df7.head(10)
# Out:
# (1247, 1)
# D:\Softwares\Anaconda_numpy\lib\site-packages\ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
#   year,TOPEX/Poseidon,Jason-1,Jason-2,Jason-3
# 0                      1992.9614,-19.43000,,,
# 1                      1992.9865,-19.84000,,,
# 2                      1993.0123,-15.50000,,,
# 3                      1993.0407,-19.31000,,,
# 4                      1993.0660,-23.83000,,,
# 5                      1993.0974,-27.12000,,,
# 6                      1993.1206,-25.01000,,,
# 7                      1993.1493,-18.88000,,,
# 8                      1993.1765,-15.82000,,,
# 9                      1993.2037,-16.22000,,,

# %%
df8=pd.read_excel("ramsar-slr-august2013.xls")
print(df8.shape)
df8
# Out:
# (8, 1)
#   Sea Level Rise Impacts on Ramsar Wetlands of International Importance, v1 (2000 – 2010)
# 0  http://sedac.ciesin.columbia.edu/data/set/lecz...
# 1  Center for International Earth Science Informa...
# 2               Earth Institute, Columbia University
# 3                                          July 2013
# 4  Suggested Citation:  Center for International ...
# 5  Abstract: This data set represents the results...
# 6  Note: Users of these data are encouraged to re...
# 7                   http://www.ramsar.org/bn/bn5.pdf

# %%
#dfx=pd.read_csv("sea_rise_txt.csv",header=None)
data = pd.read_csv('sea_rise_txt.txt', header = None)
data.head(10)
# Out:
#                                                    0
# 0    0   11  1993.0115260    466462 337277.00    ...
# 1    0   12  1993.0386920    460889 334037.31    ...
# 2    0   13  1993.0658580    472123 342416.09    ...
# 3    0   14  1993.0930250    421377 306050.59    ...
# 4    0   15  1993.1201910    459548 331094.09    ...
# 5    0   16  1993.1473570    416480 300344.81    ...
# 6    0   17  1993.1745230    467980 337061.91    ...
# 7    0   18  1993.2016890    466075 335414.41    ...
# 8    0   19  1993.2288550    461207 331521.09    ...
# 9  999   20  1993.2560210    467274 340098.59    ...

# %%
df=data.rename(columns={0:'col'})

# %%
df.head(10)
# Out:
#                                                  col
# 0    0   11  1993.0115260    466462 337277.00    ...
# 1    0   12  1993.0386920    460889 334037.31    ...
# 2    0   13  1993.0658580    472123 342416.09    ...
# 3    0   14  1993.0930250    421377 306050.59    ...
# 4    0   15  1993.1201910    459548 331094.09    ...
# 5    0   16  1993.1473570    416480 300344.81    ...
# 6    0   17  1993.1745230    467980 337061.91    ...
# 7    0   18  1993.2016890    466075 335414.41    ...
# 8    0   19  1993.2288550    461207 331521.09    ...
# 9  999   20  1993.2560210    467274 340098.59    ...

# %%
df9 = df.col.str.split(expand=True,)

# %%
df9.head(10)
# Out:
#      0   1             2       3          4       5       6       7       8  \
# 0    0  11  1993.0115260  466462  337277.00  -37.24   92.66  -37.02  -37.24
# 1    0  12  1993.0386920  460889  334037.31  -40.35   95.39  -38.20  -40.34
# 2    0  13  1993.0658580  472123  342416.09  -40.17   92.29  -38.28  -40.16
# 3    0  14  1993.0930250  421377  306050.59  -41.92   96.20  -38.56  -41.89
# 4    0  15  1993.1201910  459548  331094.09  -36.89   94.64  -37.87  -36.85
# 5    0  16  1993.1473570  416480  300344.81  -35.69   93.22  -36.96  -35.65
# 6    0  17  1993.1745230  467980  337061.91  -36.09   91.67  -36.14  -36.05
# 7    0  18  1993.2016890  466075  335414.41  -34.70   91.95  -35.53  -34.65
# 8    0  19  1993.2288550  461207  331521.09  -34.04   91.70  -35.18  -33.98
# 9  999  20  1993.2560210  467274  340098.59  -37.95  101.31  -35.09  -37.88
#
#         9      10      11
# 0   92.66  -37.02  -37.55
# 1   95.39  -38.19  -38.06
# 2   92.29  -38.27  -37.60
# ...

# %%
dfx=df9.copy()
dfx.rename(columns={0:'altimeter_type',1:'merged_file_cycle',2:'year+fraction',3:'number_obsv',4:'number_weighted_obsv',
                   5:'gmsl',6:'std_dev_gmsl',7:'smoothed_gmsl',8:'gmsl_variation',9:'std_dev_gmsl_variation',
                   10:'smoothed_gmsl_variation_1',11:'smoothed_gmsl_variation_2'},inplace=True)

# %%
dfx.tail(10)
# Out:
#      altimeter_type merged_file_cycle year+fraction number_obsv  \
# 996               0              1008  2020.0795240      288360
# 997               0              1009  2020.1066160       52754
# 998               0              1010  2020.1337080      476471
# 999               0              1011  2020.1608000      478893
# 1000              0              1012  2020.1878910      478815
# 1001              0              1013  2020.2149830      477607
# 1002              0              1014  2020.2420750      479899
# 1003              0              1015  2020.2691670      477366
# 1004              0              1016  2020.2962590      480955
# 1005              0              1017  2020.3233510      480308
#
#      number_weighted_obsv   gmsl std_dev_gmsl smoothed_gmsl gmsl_variation  \
# 996             207875.91  47.87        97.45         46.39          55.29
# 997              37334.80  41.19       100.84         46.16          49.06
# ...

# %%
dfx.dtypes
# Out:
# altimeter_type               object
# merged_file_cycle            object
# year+fraction                object
# number_obsv                  object
# number_weighted_obsv         object
# gmsl                         object
# std_dev_gmsl                 object
# smoothed_gmsl                object
# gmsl_variation               object
# std_dev_gmsl_variation       object
# smoothed_gmsl_variation_1    object
# smoothed_gmsl_variation_2    object
# dtype: object

# %%
from datetime import timedelta, datetime

def convert_partial_year(number):

    year = int(float(number))
    d = timedelta(days=(float(number) - year)*365)
    day_one = datetime(year,1,1)
    date = d + day_one
    return date

# %%
dfx["try"]=dfx["year+fraction"].apply(lambda x:convert_partial_year(x))

# %%
dfy=dfx[["altimeter_type","merged_file_cycle","year+fraction","number_obsv","number_weighted_obsv","gmsl","std_dev_gmsl",
     "smoothed_gmsl","gmsl_variation","std_dev_gmsl_variation","smoothed_gmsl_variation_1","smoothed_gmsl_variation_2"]].astype(float)

# %%
dfy["date"]=dfx["try"]

# %%
dfy.tail(10)
# Out:
#       altimeter_type  merged_file_cycle  year+fraction  number_obsv  \
# 996              0.0             1008.0    2020.079524     288360.0
# 997              0.0             1009.0    2020.106616      52754.0
# 998              0.0             1010.0    2020.133708     476471.0
# 999              0.0             1011.0    2020.160800     478893.0
# 1000             0.0             1012.0    2020.187891     478815.0
# 1001             0.0             1013.0    2020.214983     477607.0
# 1002             0.0             1014.0    2020.242075     479899.0
# 1003             0.0             1015.0    2020.269167     477366.0
# 1004             0.0             1016.0    2020.296259     480955.0
# 1005             0.0             1017.0    2020.323351     480308.0
#
#       number_weighted_obsv   gmsl  std_dev_gmsl  smoothed_gmsl  \
# 996              207875.91  47.87         97.45          46.39
# 997               37334.80  41.19        100.84          46.16
# ...

# %%
dfy.plot(kind='line',x='date',y='gmsl')
plt.ylabel('Global Mean Sea Level')
plt.xlabel('Year')
plt.title('Rise in GMSL with time')
plt.savefig('GMSL.png')

# %%
dfy.plot(kind='line',x='date',y='std_dev_gmsl')
plt.ylabel('Standard Deviation of Global Mean Sea Level')
plt.xlabel('Year')
plt.title('Change in Std Dev of GMSL with time')
plt.savefig('std_dev_GMSL.png')

# %%
dfy.plot(kind='line',x='date',y='smoothed_gmsl')
plt.ylabel('Smoothened Global Mean Sea Level Value')
plt.xlabel('Year')
plt.title('Smoothened gmsl with time')
plt.savefig('smoothened_GMSL.png')

# %%
dfy.plot(kind='line',x='date',y='gmsl_variation')
plt.ylabel('Variance of Global Mean Sea Level')
plt.xlabel('Year')
plt.title('Change in variance of GMSL with time')
plt.savefig('variance_GMSL.png')

# %%
dfy.plot(kind='line',x='date',y='smoothed_gmsl_variation_1')
plt.ylabel('Smoothened Variance in Global Mean Sea Level')
plt.xlabel('Year')
plt.title("Variance(smoothened) GMSL with time")
plt.savefig('smoothened_variance_GMSL.png')

# %%
dfy.plot(kind='line',x='date',y='smoothed_gmsl_variation_2')
plt.ylabel('Smoothened Variance in Global Mean Sea Level')
plt.xlabel('Year')
plt.title("Variance(smoothened) wrt last 20 year's mean GMSL with time")
plt.savefig('smoothened_variance_GMSL_wrt_mean.png')

# %%
dfy.plot(kind='line',x='date',y='std_dev_gmsl_variation')

# %%
import datetime as dt
dfx["epoch"]=(dfx['try'] - dt.datetime(1970,1,1)).dt.total_seconds()

# %%
dfx.tail()
# Out:
#      altimeter_type merged_file_cycle year+fraction number_obsv  \
# 1001              0              1013  2020.2149830      477607
# 1002              0              1014  2020.2420750      479899
# 1003              0              1015  2020.2691670      477366
# 1004              0              1016  2020.2962590      480955
# 1005              0              1017  2020.3233510      480308
#
#      number_weighted_obsv   gmsl std_dev_gmsl smoothed_gmsl gmsl_variation  \
# 1001            344359.59  45.89        98.80         46.85          53.36
# 1002            345641.59  47.05        99.30         46.79          54.59
# 1003            343801.09  47.61        98.83         46.74          55.20
# 1004            344891.19  45.26        96.20         46.69          52.83
# 1005            345087.09  46.42        95.79         46.66          53.99
#
#      std_dev_gmsl_variation smoothed_gmsl_variation_1  \
# 1001                 101.27                     54.38
# ...

# %%
dfy["epoch"]=dfx["epoch"]

# %%
from matplotlib import style
style.use('ggplot')

from sklearn import linear_model
regr = linear_model.LinearRegression()
train_x = np.asanyarray(dfy[['epoch']])
train_y = np.asanyarray(dfy[['smoothed_gmsl_variation_2']])
regr.fit (train_x, train_y)
# The coefficients
print ('Coefficients: ', regr.coef_)
print ('Intercept: ',regr.intercept_)
# Out:
# Coefficients:  [[1.05461767e-07]]
# Intercept:  [-114.82599933]

# %%
train_x[-10:]
# Out:
# array([[1.58034467e+09],
#        [1.58119904e+09],
#        [1.58205342e+09],
#        [1.58290779e+09],
#        [1.58376213e+09],
#        [1.58461650e+09],
#        [1.58547088e+09],
#        [1.58632525e+09],
#        [1.58717962e+09],
#        [1.58803400e+09]])

# %%
samp=(dt.datetime(2030,1,1) - dt.datetime(1970,1,1)).total_seconds()

# %%
regr.predict([[1700000000]])
# Out:
# array([[64.45900497]])

# %%
plt.scatter(dfy.epoch, dfy.smoothed_gmsl_variation_2,  color='blue')
plt.plot(train_x, regr.coef_[0][0] * train_x + regr.intercept_[0], '-r')
plt.xlabel("Time")
plt.ylabel("Global Mean Sea Level variation")
# Out:
# Text(0, 0.5, 'Global Mean Sea Level variation')

# %%
import seaborn as sns
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.regplot(x='epoch',y='smoothed_gmsl_variation_2', data=dfy)
plt.ylim(0,)
# Out:
# (0, 64.29904259897435)

# %%
df10 = pd.read_csv("beautifulsoup.csv")
df10.head()
# Out:
#         Country             Elevation
# 0           NaN                   NaN
# 1   Afghanistan  1,885 m (6,184 ft)\n
# 2       Albania    708 m (2,323 ft)\n
# 3       Algeria    800 m (2,625 ft)\n
# 4       Andorra  1,996 m (6,549 ft)\n

# %%
df11 = df10.Elevation.str.split(expand=True,)

# %%
df11.head()
# Out:
#        0    1       2    3
# 0    NaN  NaN     NaN  NaN
# 1  1,885    m  (6,184  ft)
# 2    708    m  (2,323  ft)
# 3    800    m  (2,625  ft)
# 4  1,996    m  (6,549  ft)

# %%
df11.shape
# Out:
# (170, 4)

# %%
df10.shape
# Out:
# (170, 2)

# %%
df11.rename(columns={0:'elevation_in_metre'},inplace=True)

# %%
df10["elevation_m"]=df11["elevation_in_metre"]

# %%
df10.head()
# Out:
#         Country             Elevation elevation_m
# 0           NaN                   NaN         NaN
# 1   Afghanistan  1,885 m (6,184 ft)\n       1,885
# 2       Albania    708 m (2,323 ft)\n         708
# 3       Algeria    800 m (2,625 ft)\n         800
# 4       Andorra  1,996 m (6,549 ft)\n       1,996

# %%
df10.drop(['Elevation'],axis=1,inplace=True)
df10.head()
# Out:
#         Country elevation_m
# 0           NaN         NaN
# 1   Afghanistan       1,885
# 2       Albania         708
# 3       Algeria         800
# 4       Andorra       1,996

# %%
df10.dropna().shape
# Out:
# (169, 2)

# %%
df10.shape
# Out:
# (170, 2)

# %%
def convert_to_int(string):
    ro=[]
    x=''
    for number in string:
        if(number==','):
            pass
        else:
            #ro.append(number)
            x += number
    return float(x)

# %%
df10.dtypes
# Out:
# Country        object
# elevation_m    object
# dtype: object

# %%
df10["elevation_m_try"]=df10["elevation_m"].apply(lambda x:convert_to_int(str(x)))

# %%
df10.head()
# Out:
#         Country elevation_m  elevation_m_try
# 0           NaN         NaN              NaN
# 1   Afghanistan       1,885           1885.0
# 2       Albania         708            708.0
# 3       Algeria         800            800.0
# 4       Andorra       1,996           1996.0

# %%
dfwiki=df10.dropna()

# %%
dfwiki.drop(["elevation_m"],axis=1,inplace=True)
dfwiki.head()
# Out:
# D:\Softwares\Anaconda_numpy\lib\site-packages\pandas\core\frame.py:4117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#         Country  elevation_m_try
# 1   Afghanistan           1885.0
# 2       Albania            708.0
# 3       Algeria            800.0
# 4       Andorra           1996.0
# 5        Angola           1112.0

# %%
dfwiki.shape
# Out:
# (169, 2)

# %%
dfpop=df2.copy()
dfpop.rename(columns={"PLACE_NAME":"Country"},inplace=True)

# %%
dfpop.head()
# Out:
#                Country   TOTAL      x0m     x1m     x2m     x3m     x4m  \
# 0              Albania   3.000  0.05000  0.1200  0.1600  0.2300  0.2800
# 1              Algeria  35.000  0.03500  0.0540  0.3600  0.7500  0.9600
# 2       American Samoa   0.066  0.00250  0.0050  0.0070  0.0086  0.0098
# 3               Angola  13.000  0.00380  0.0140  0.1300  0.2900  0.3700
# 4  Antigua and Barbuda   0.087  0.00036  0.0015  0.0036  0.0093  0.0130
#
#      x5m    x6m    x7m    x8m    x9m   x10m
# 0  0.320  0.350  0.380  0.410  0.440  0.470
# 1  1.100  1.200  1.300  1.400  1.500  1.600
# 2  0.011  0.012  0.013  0.014  0.015  0.015
# 3  0.430  0.480  0.510  0.540  0.570  0.590
# 4  0.016  0.018  0.020  0.021  0.023  0.024

# %%
dfpop[dfpop["Country"]=="India"]
# Out:
#    Country   TOTAL   x0m   x1m   x2m   x3m   x4m   x5m   x6m   x7m    x8m  \
# 70   India  1170.0  17.0  29.0  42.0  56.0  67.0  78.0  87.0  95.0  100.0
#
#       x9m   x10m
# 70  110.0  110.0

# %%
dfwiki.tail()
# Out:
#              Country  elevation_m_try
# 165   Western Sahara            256.0
# 166            Yemen            999.0
# 167           Zambia           1138.0
# 168         Zimbabwe            961.0
# 169            World            840.0

# %%
def name_issue(name):
    x=''
    for i in name:
        if(i==' '):
            pass
        else:
            x += i
    return x

# %%
dfwiki["name_try"]=dfwiki["Country"].apply(lambda x:name_issue(x))
# Out:
# D:\Softwares\Anaconda_numpy\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dfpop["name_try"]=dfpop["Country"].apply(lambda x:name_issue(x))

# %%
dfwiki["elev_mm"]=dfwiki["elevation_m_try"]*1000
# Out:
# D:\Softwares\Anaconda_numpy\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dfwiki.tail(2)
# Out:
#        Country  elevation_m_try   name_try   elev_mm
# 168   Zimbabwe            961.0   Zimbabwe  961000.0
# 169      World            840.0      World  840000.0

# %%
dfwiki["elev_mm"].mean()
# Out:
# 650584.6153846154

# %%
dfpop.tail(2)
# Out:
#     Country   TOTAL      x0m     x1m     x2m     x3m    x4m     x5m    x6m  \
# 173   Yemen    24.0    0.031    0.11    0.52    0.68    0.8    0.91    1.0
# 174   World  6840.0  110.000  230.00  400.00  550.00  680.0  770.00  840.0
#
#        x7m    x8m     x9m    x10m name_try
# 173    1.1    1.1     1.2     1.3    Yemen
# 174  900.0  950.0  1000.0  1040.0    World

# %%
dfy.tail(2)
# Out:
#       altimeter_type  merged_file_cycle  year+fraction  number_obsv  \
# 1004             0.0             1016.0    2020.296259     480955.0
# 1005             0.0             1017.0    2020.323351     480308.0
#
#       number_weighted_obsv   gmsl  std_dev_gmsl  smoothed_gmsl  \
# 1004             344891.19  45.26         96.20          46.69
# 1005             345087.09  46.42         95.79          46.66
#
#       gmsl_variation  std_dev_gmsl_variation  smoothed_gmsl_variation_1  \
# 1004           52.83                   98.67                      54.23
# 1005           53.99                   98.39                      54.20
#
#       smoothed_gmsl_variation_2                       date         epoch
# 1004                      57.10 2020-04-18 03:13:43.823999  1.587180e+09
# 1005                      57.41 2020-04-28 00:33:17.136000  1.588034e+09

# %%
#reverse

regr1 = linear_model.LinearRegression()
train_y = np.asanyarray(dfy[['epoch']])
train_x = np.asanyarray(dfy[['smoothed_gmsl_variation_2']])
regr.fit (train_x, train_y)
# The coefficients
print ('Coefficients: ', regr.coef_)
print ('Intercept: ',regr.intercept_)
plt.scatter(dfy.smoothed_gmsl_variation_2,dfy.epoch,  color='blue')
plt.plot(train_x, regr.coef_[0][0] * train_x + regr.intercept_[0], '-r')
plt.ylabel("Time")
plt.xlabel("Global Mean Sea Level variation")
# Out:
# Coefficients:  [[9264469.09283385]]
# Intercept:  [1.09036098e+09]
# Text(0.5, 0, 'Global Mean Sea Level variation')

# %%
train_x[-5:]
# Out:
# array([[56.46],
#        [56.61],
#        [56.83],
#        [57.1 ],
#        [57.41]])

# %%
a = np.asanyarray(dfwiki["elev_mm"].tolist())

# %%
a
# Out:
# array([1.885e+06, 7.080e+05, 8.000e+05, 1.996e+06, 1.112e+06, 2.300e+06,
#        5.950e+05, 1.792e+06, 3.300e+05, 9.100e+05, 3.840e+05, 8.500e+04,
#        1.600e+05, 1.810e+05, 1.730e+05, 2.730e+05, 3.280e+06, 1.192e+06,
#        5.000e+05, 1.013e+06, 3.200e+05, 4.780e+05, 4.720e+05, 2.970e+05,
#        1.504e+06, 1.260e+05, 6.670e+05, 4.870e+05, 6.350e+05, 5.430e+05,
#        1.871e+06, 1.840e+06, 5.930e+05, 4.300e+05, 7.260e+05, 5.680e+05,
#        7.460e+05, 3.310e+05, 1.080e+05, 9.100e+04, 4.330e+05, 3.400e+04,
#        4.300e+05, 4.240e+05, 1.117e+06, 3.210e+05, 4.420e+05, 6.100e+04,
#        5.770e+05, 8.530e+05, 1.330e+06, 1.640e+05, 3.750e+05, 1.680e+05,
#        3.770e+05, 3.400e+04, 1.432e+06, 2.630e+05, 1.900e+05, 4.980e+05,
#        1.792e+06, 7.590e+05, 4.720e+05, 7.000e+04, 2.070e+05, 4.700e+05,
#        6.840e+05, 1.430e+05, 5.570e+05, 6.210e+05, 3.670e+05, 1.305e+06,
#        3.120e+05, 1.180e+05, 5.080e+05, 5.380e+05, 2.500e+05, 3.400e+05,
# ...

# %%
a=a.reshape(-1,1)

# %%
expected_submerging = regr.predict(a)

# %%
dfwiki[dfwiki["predictions"]==dfwiki["predictions"].min()]
# Out:
#       Country  elevation_m_try   name_try  elev_mm   predictions  \
# 97   Maldives              1.8   Maldives   1800.0  1.776641e+10
#
#                   date
# 97 1901-12-13 20:45:52

# %%
regr.predict([[]])

# %%
type(expected_submerging)
# Out:
# numpy.ndarray

# %%
ticks = expected_submerging.astype('datetime64[s]').tolist()

# %%
pred1=np.asarray(ticks)

# %%
dfwiki["predictions"]=ticks
# Out:
# D:\Softwares\Anaconda_numpy\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dfwiki.head()
# Out:
#         Country  elevation_m_try      name_try    elev_mm       predictions  \
# 1   Afghanistan           1885.0   Afghanistan  1885000.0  [17464614600968]
# 2       Albania            708.0       Albania   708000.0   [6560334478703]
# 3       Algeria            800.0       Algeria   800000.0   [7412665635244]
# 4       Andorra           1996.0       Andorra  1996000.0  [18492970670273]
# 5        Angola           1112.0        Angola  1112000.0  [10303179992208]
#
#                            date
# 1 2025-05-05 16:11:00.096879959
# 2 1990-10-15 23:30:47.870336056
# 3 1993-06-28 11:22:43.524407387
# 4 2028-08-07 21:37:47.027335882
# 5 2002-08-25 23:26:39.220823646

# %%
def list_to_numb(inp):
    m=''
    for i in inp:
        for n in i:
            if(i not in range(0,10)):
                pass
            else:
                m += i
    return m

# %%
dfwiki["pred"]=dfwiki["predictions"].apply(lambda x:list_to_numb(str(x)))
# Out:
# D:\Softwares\Anaconda_numpy\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dfwiki=dfwiki.drop(["pred"],axis=1)

# %%
final_df = dfwiki.drop(["elevation_m_try","name_try","date"],axis=1)

# %%
final_df
# Out:
#              Country    elev_mm   predictions
# 1        Afghanistan  1885000.0  1.746461e+13
# 2            Albania   708000.0  6.560334e+12
# 3            Algeria   800000.0  7.412666e+12
# 4            Andorra  1996000.0  1.849297e+13
# 5             Angola  1112000.0  1.030318e+13
# ..               ...        ...           ...
# 165   Western Sahara   256000.0  2.372794e+12
# 166            Yemen   999000.0  9.256295e+12
# 167           Zambia  1138000.0  1.054406e+13
# 168         Zimbabwe   961000.0  8.904245e+12
# 169            World   840000.0  7.783244e+12
#
# [169 rows x 3 columns]

# %%
final_df[final_df["predictions"]==final_df["predictions"].min()]
# Out:
#       Country  elev_mm   predictions
# 97   Maldives   1800.0  1.776641e+10

# %%
final_df["predictions"].mean()
# Out:
# 6028411422480.962

# %%
final_df.groupby("predictions")["Country"].min()
# Out:
# predictions
# 1.776641e+10        Maldives
# 1.400574e+11     Singapore\n
# 2.604955e+11           Qatar
# 2.790244e+11     Netherlands
# 3.160823e+11         Denmark
#                     ...
# 2.130937e+13      Antarctica
# 2.768332e+13      Kyrgyzstan
# 2.951769e+13      Tajikistan
# 3.024958e+13           Nepal
# 3.038855e+13          Bhutan
# Name: Country, Length: 155, dtype: object

# %%
#maldives Monday, December 29, 2532
#singapore 
#qATAR 
#netherlands 
#denmark
